# %%
library(glmnet)
rm(list=ls())
source("/Users/canyang/Documents/github_Yang/statistical-learning/Statistical-Machine-Learning/Lasso.R")
# set.seed(10)
ntrain <- 100
p <- 1000
c0 <- 2
xtrain <- 2*matrix(rnorm(ntrain*p),ntrain,p) + c0
xtrain[,1] <- xtrain[,1] * 3

b <- rep(0,p)
b[1:10] <- rnorm(10)

b0 <- 1
ytrain <- xtrain%*%b + b0 + rnorm(ntrain,0,sqrt(var(xtrain%*%b)))#rnorm(ntrain,0,1)

# centerize xtrain
cc <- colMeans(xtrain)
xtrain2 <- t(t(xtrain) - cc)

# standardize xtrain?
standardizeX <- T

if(standardizeX){
  s <- sqrt(colMeans(xtrain2^2))
  xtrain2 <- t(t(xtrain2)/s)
}

# get lambda sequence
MaxLam <- max(abs(t(xtrain2)%*%ytrain))
loglam <- seq(log10(MaxLam),log10(0.2*MaxLam),length.out = 100)
# loglam <- seq(2*log10(p^2),-log10(p^2),length.out = 100)
lam <- 10^(loglam)#exp(loglam)
# Out:
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-16

# %%
# fit using glmnet
fitglmnet <- glmnet(xtrain,ytrain,alpha=1,lambda = lam/ntrain,standardize = T,thresh = 1e-10)

fitLasso1 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam,method="ACD")
fitLasso2 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam,method="CD")
fitLasso3 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam,method="GD")
fitLasso4 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam,method="AGD")
# Out:
#  Finished!	 1  outer loops;	 0  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 4  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 10  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 10  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 12  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 14  inner loops
#  Finished!	 3  outer loops;	 14  inner loops
#  Finished!	 3  outer loops;	 14  inner loops
#  Finished!	 3  outer loops;	 14  inner loops
#  Finished!	 3  outer loops;	 14  inner loops
#  Finished!	 3  outer loops;	 13  inner loops
#  Finished!	 3  outer loops;	 16  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 19  inner loops
#  Finished!	 3  outer loops;	 19  inner loops
#  Finished!	 3  outer loops;	 19  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 18  inner loops
#  Finished!	 3  outer loops;	 19  inner loops
#  Finished!	 3  outer loops;	 21  inner loops
#  Finished!	 3  outer loops;	 21  inner loops
#  Finished!	 3  outer loops;	 28  inner loops
#  Finished!	 4  outer loops;	 30  inner loops
#  Finished!	 3  outer loops;	 41  inner loops
#  Finished!	 3  outer loops;	 38  inner loops
#  Finished!	 3  outer loops;	 39  inner loops
#  Finished!	 3  outer loops;	 39  inner loops
#  Finished!	 3  outer loops;	 39  inner loops
#  Finished!	 3  outer loops;	 39  inner loops
#  Finished!	 4  outer loops;	 61  inner loops
#  Finished!	 3  outer loops;	 42  inner loops
#  Finished!	 3  outer loops;	 45  inner loops
#  Finished!	 3  outer loops;	 44  inner loops
#  Finished!	 3  outer loops;	 44  inner loops
#  Finished!	 3  outer loops;	 43  inner loops
#  Finished!	 3  outer loops;	 44  inner loops
#  Finished!	 3  outer loops;	 45  inner loops
#  Finished!	 3  outer loops;	 46  inner loops
#  Finished!	 3  outer loops;	 48  inner loops
#  Finished!	 4  outer loops;	 62  inner loops
#  Finished!	 3  outer loops;	 48  inner loops
#  Finished!	 3  outer loops;	 47  inner loops
#  Finished!	 3  outer loops;	 47  inner loops
#  Finished!	 3  outer loops;	 46  inner loops
#  Finished!	 4  outer loops;	 78  inner loops
#  Finished!	 1  loops
#  Finished!	 4  loops
#  Finished!	 4  loops
#  Finished!	 4  loops
#  Finished!	 4  loops
#  Finished!	 4  loops
#  Finished!	 4  loops
#  Finished!	 5  loops
#  Finished!	 6  loops
#  Finished!	 6  loops
#  Finished!	 74  loops
#  Finished!	 165  loops
#  Finished!	 182  loops
#  Finished!	 149  loops
#  Finished!	 139  loops
#  Finished!	 157  loops
#  Finished!	 150  loops
#  Finished!	 128  loops
#  Finished!	 122  loops
#  Finished!	 171  loops
#  Finished!	 166  loops
#  Finished!	 166  loops
#  Finished!	 166  loops
#  Finished!	 166  loops
#  Finished!	 88  loops
#  Finished!	 157  loops
#  Finished!	 132  loops
#  Finished!	 186  loops
#  Finished!	 153  loops
#  Finished!	 151  loops
#  Finished!	 115  loops
#  Finished!	 128  loops
#  Finished!	 121  loops
#  Finished!	 204  loops
#  Finished!	 122  loops
#  Finished!	 117  loops
#  Finished!	 52  loops
#  Finished!	 68  loops
#  Finished!	 172  loops
#  Finished!	 166  loops
#  Finished!	 160  loops
#  Finished!	 173  loops
#  Finished!	 124  loops
#  Finished!	 145  loops
#  Finished!	 146  loops
#  Finished!	 104  loops
#  Finished!	 99  loops
#  Finished!	 106  loops
#  Finished!	 106  loops
#  Finished!	 85  loops
#  Finished!	 131  loops
#  Finished!	 80  loops
#  Finished!	 124  loops

# %%
par(mfrow=c(2,3))
# matplot(-log(lam),t(fitglmnet$beta),pch=20)
# matplot(-log(lam),t(fitLasso$beta),pch=20)
matplot(-log(lam),t(fitglmnet$beta),type="l",xlab="log(lambda)",ylab="beta",main="glmnet")
matplot(-log(lam),t(fitLasso1$beta),type="l",xlab="log(lambda)",ylab="beta",main="my CD with active set")
matplot(-log(lam),t(fitLasso2$beta),type="l",xlab="log(lambda)",ylab="beta",main="my CD")
matplot(-log(lam),t(fitLasso3$beta),type="l",xlab="log(lambda)",ylab="beta",main="my GD")
matplot(-log(lam),t(fitLasso4$beta),type="l",xlab="log(lambda)",ylab="beta",main="my GD with momentum")
# Out:
# Plot with title “my GD with momentum”

# %%
rm(list=ls())
source("/Users/canyang/Documents/github_Yang/statistical-learning/Statistical-Machine-Learning/Lasso.R")

n_rep <- 10

err <- vector("list",4)
err[[1]] <- err[[2]] <- err[[3]] <- err[[4]] <- vector("list",10)



for(i in 1:n_rep){
  ntrain <- 100
  p <- 1000
  c0 <- 2
  # xtrain <- matrix(rnorm(ntrain*p),ntrain,p)
  xtrain <- 2*matrix(rnorm(ntrain*p),ntrain,p) + c0
  xtrain[,1] <- xtrain[,1] * 3
  
  b <- rep(0,p)
  b[1:10] <- rnorm(10)
  
  b0 <- 1
  ytrain <- xtrain%*%b + b0 + rnorm(ntrain,0,sqrt(9*var(xtrain%*%b)))
  
  # centerize xtrain
  cc <- colMeans(xtrain)
  xtrain2 <- t(t(xtrain) - cc)
  
  # standardize xtrain?
  standardizeX <- T
  
  if(standardizeX){
    s <- sqrt(colMeans(xtrain2^2))
    xtrain2 <- t(t(xtrain2)/s)
  }
  
  # get lambda sequence
  MaxLam <- max(abs(t(xtrain2)%*%ytrain))
  loglam <- seq(log10(MaxLam),log10(0.2*MaxLam),length.out = 100)
  # loglam <- seq(2*log10(p^2),-log10(p^2),length.out = 100)
  lam <- 10^(loglam)#exp(loglam)
  
  fitLasso1 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam[50],method="ACD")
  fitLasso2 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam[50],method="CD")
  fitLasso3 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam[50],method="GD")
  fitLasso4 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam[50],method="AGD")
  
  # err[[1]][[i]] <- log(fitLasso1$obj[[1]]-tail(fitLasso1$obj[[1]],1))
  # err[[2]][[i]] <- log(fitLasso2$obj[[1]]-tail(fitLasso2$obj[[1]],1))
  # err[[3]][[i]] <- log(fitLasso3$obj[[1]]-tail(fitLasso3$obj[[1]],1))
  # err[[4]][[i]] <- log(fitLasso4$obj[[1]]-tail(fitLasso4$obj[[1]],1))
  
  err[[1]][[i]] <- (fitLasso1$obj[[1]]-tail(fitLasso1$obj[[1]],1))/tail(fitLasso1$obj[[1]],1)
  err[[2]][[i]] <- (fitLasso2$obj[[1]]-tail(fitLasso2$obj[[1]],1))/tail(fitLasso2$obj[[1]],1)
  err[[3]][[i]] <- (fitLasso3$obj[[1]]-tail(fitLasso3$obj[[1]],1))/tail(fitLasso3$obj[[1]],1)
  err[[4]][[i]] <- (fitLasso4$obj[[1]]-tail(fitLasso4$obj[[1]],1))/tail(fitLasso4$obj[[1]],1)
}
# Out:
#  Finished!	 4  outer loops;	 31  inner loops
#  Finished!	 17  loops
#  Finished!	 497  loops
#  Finished!	 999  loops
#  Finished!	 4  outer loops;	 34  inner loops
#  Finished!	 24  loops
#  Finished!	 618  loops
#  Finished!	 999  loops
#  Finished!	 4  outer loops;	 37  inner loops
#  Finished!	 22  loops
#  Finished!	 645  loops
#  Finished!	 999  loops
#  Finished!	 4  outer loops;	 56  inner loops
#  Finished!	 34  loops
#  Finished!	 754  loops
#  Finished!	 999  loops
#  Finished!	 4  outer loops;	 38  inner loops
#  Finished!	 23  loops
#  Finished!	 432  loops
#  Finished!	 999  loops
#  Finished!	 5  outer loops;	 55  inner loops
#  Finished!	 23  loops
#  Finished!	 568  loops
#  Finished!	 999  loops
#  Finished!	 5  outer loops;	 79  inner loops
#  Finished!	 34  loops
#  Finished!	 906  loops
#  Finished!	 999  loops
#  Finished!	 4  outer loops;	 41  inner loops
#  Finished!	 21  loops
#  Finished!	 572  loops
#  Finished!	 999  loops
#  Finished!	 6  outer loops;	 58  inner loops
#  Finished!	 19  loops
#  Finished!	 656  loops
#  Finished!	 999  loops
#  Finished!	 5  outer loops;	 54  inner loops
#  Finished!	 24  loops
#  Finished!	 742  loops
#  Finished!	 999  loops

# %%
library(ggplot2)
cutoff <- 40
method <- c("ACD","CD","GD","AGD")
out <- data.frame()

i_line <- 0
for(k in 1:4){
  for(i in 1:n_rep){
    i_line <- i_line + 1
    out <- rbind(out,data.frame((err[[k]][[i]][1:cutoff]),1:cutoff,method[k],i_line),row.names=NULL)
  }
}
out <- do.call(data.frame,lapply(out, function(x) replace(x, is.infinite(x),NA)))
names(out) <- c("error","iteration","method","line")
ggplot(out,aes(y=error,x=iteration,color=method,group=line)) +
  geom_line() + scale_y_log10(limits=c(1e-10,NA))
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 494 rows containing missing values (geom_path).”
# plot without title
