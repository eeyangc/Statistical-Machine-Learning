# %%
# Generate data
n = 500
p = 2
y = c(rep(0,n/2),rep(1,n/2))
x_class1 = matrix(rnorm(n/2*p),n/2,p)-1
x_class2 = matrix(rnorm(n/2*p),n/2,p)+1
x = rbind(x_class1,x_class2)
data = as.data.frame(cbind(y,x))
names(data) = c("y",paste("x",1:p,sep=""))

# %%
library(ggplot2)
data$y=as.factor(data$y)
qplot(x=x1, y=x2, data=data, color=y)
# Out:
# plot without title

# %%
glm.fit = glm(y~x1+x2,family = "binomial",data=data)

# %%
summary(glm.fit)
# Out:
# Call:
# glm(formula = y ~ x1 + x2, family = "binomial", data = data)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -3.15899  -0.29721   0.00088   0.26115   2.49386
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   0.1693     0.1659   1.020    0.308
# x1            1.8097     0.2121   8.534  < 2e-16 ***
# x2            1.4661     0.1822   8.045 8.64e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 693.15  on 499  degrees of freedom
# Residual deviance: 243.80  on 497  degrees of freedom
# AIC: 249.8
#
# Number of Fisher Scoring iterations: 6

# %%
# A failed case
# Generate data
n = 500
p = 2
y = c(rep(0,n/2),rep(1,n/2))
x_class1 = matrix(rnorm(n/2*p),n/2,p)-3
x_class2 = matrix(rnorm(n/2*p),n/2,p)+3
x = rbind(x_class1,x_class2)
data = as.data.frame(cbind(y,x))
names(data) = c("y",paste("x",1:p,sep=""))

# %%
library(ggplot2)
data$y=as.factor(data$y)
p<- ggplot(data=data, aes(x=x1, y=x2,color=y))+ geom_point()
p
# Out:
# plot without title

# %%
glm.fit = glm(y~x1+x2,family = "binomial",data=data)
# Out:
# Warning message:
# “glm.fit: algorithm did not converge”Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”

# %%
summary(glm.fit)
# Out:
# Call:
# glm(formula = y ~ x1 + x2, family = "binomial", data = data)
#
# Deviance Residuals:
#        Min          1Q      Median          3Q         Max
# -7.485e-05  -2.100e-08   0.000e+00   2.100e-08   5.353e-05
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -4.354   9951.566   0.000    1.000
# x1             8.674   7766.509   0.001    0.999
# x2             7.321   7863.733   0.001    0.999
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 6.9315e+02  on 499  degrees of freedom
# Residual deviance: 1.0934e-08  on 497  degrees of freedom
# AIC: 6
#
# Number of Fisher Scoring iterations: 25

# %%
mylogistic <- function(y,x){
  maxIter = 100
  n = dim(x)[1]
  p = dim(x)[2]
  
  x = cbind(matrix(1,n,1),x)
  XtX = t(x)%*%x
  
  w_old = matrix(0,p+1,1)
  prob = 1/(1+exp(-x%*%w_old))

   for (iter in 1:maxIter){
     z =  0.25*x%*%w_old + (y-prob);
     w = solve(0.25*XtX)%*%(t(x)%*%z);
  
     if (max(abs(w_old-w))/sqrt(sum(w^2)) < 1e-4){
       break
     }
     prob = 1/(1+exp(-x%*%w))
     prob[prob>0.999] = 0.999
     prob[prob<0.001] = 0.001
  
     w_old = w
  }
  return(list(prob=prob,w=w,Iter = iter)) 
}

# %%
my.fit<- mylogistic(y=as.numeric(data$y)-1,x=as.matrix(data[,2:3]))

# %%
my.fit$w
# Out:
#    [,1]
#    -0.1285477
# x1  1.1537920
# x2  0.9949255

# %%
my.fit$Iter
# Out:
# [1] 100

# %%
getwd()
# Out:
# [1] "/Users/canyang/Documents/github_Yang/statistical-learning/Statistical-Machine-Learning"

# %%
setwd("/Users/canyang/Documents/github_Yang/statistical-learning/Statistical-Machine-Learning/")
